# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt
import os

# %%
data = pd.read_csv("D:\\Thyroid_disease_detection\\thyroid0387.data.csv")

# %%
data.head()
# Out:
#    29  F  f f.1 f.2 f.3 f.4 f.5 f.6  t  ... f.14  ?.1 f.15 ?.2 f.16 ?.3 f.17  \
# 0  29  F  f   f   f   f   f   f   f  f  ...    t  128    f   ?    f   ?    f
# 1  41  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
# 2  36  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
# 3  32  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
# 4  60  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
#
#   ?.4  other  -[840801013]
# 0   ?  other  -[840801014]
# 1  11  other  -[840801042]
# 2  26  other  -[840803046]
# 3  36  other  S[840803047]
# 4  26  other  -[840803048]
#
# [5 rows x 30 columns]

# %%
data.tail()
# Out:
#       29  F  f f.1 f.2 f.3 f.4 f.5 f.6  t  ... f.14  ?.1 f.15   ?.2 f.16 ?.3  \
# 9166  56  M  f   f   f   f   f   f   f  f  ...    t   64    t  0.83    t  77
# 9167  22  M  f   f   f   f   f   f   f  f  ...    t   91    t  0.92    t  99
# 9168  69  M  f   f   f   f   f   f   f  f  ...    t  113    t  1.27    t  89
# 9169  47  F  f   f   f   f   f   f   f  f  ...    t   75    t  0.85    t  88
# 9170  31  M  f   f   f   f   f   f   f  t  ...    t   66    t  1.02    t  65
#
#      f.17 ?.4  other  -[840801013]
# 9166    f   ?    SVI  -[870119022]
# 9167    f   ?    SVI  -[870119023]
# 9168    f   ?    SVI  I[870119025]
# 9169    f   ?  other  -[870119027]
# 9170    f   ?  other  -[870119035]
#
# [5 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9171 entries, 0 to 9170
# Data columns (total 30 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   29            9171 non-null   int64
#  1   F             9171 non-null   object
#  2   f             9171 non-null   object
#  3   f.1           9171 non-null   object
#  4   f.2           9171 non-null   object
#  5   f.3           9171 non-null   object
#  6   f.4           9171 non-null   object
#  7   f.5           9171 non-null   object
#  8   f.6           9171 non-null   object
#  9   t             9171 non-null   object
#  10  f.7           9171 non-null   object
#  11  f.8           9171 non-null   object
#  12  f.9           9171 non-null   object
#  13  f.10          9171 non-null   object
#  14  f.11          9171 non-null   object
#  15  f.12          9171 non-null   object
#  16  t.1           9171 non-null   object
#  17  0.3           9171 non-null   object
# ...

# %% [markdown]
# ---> Here all the columns are object datatypes except one column so all the columns needed to be preprocessed

# %%
data.describe().T
# Out:
#      count      mean          std  min   25%   50%   75%      max
# 29  9171.0  73.56068  1184.041182  1.0  37.0  55.0  68.0  65526.0

# %%
data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ---> Null values are not present

# %% [markdown]
# here we are going to save the first character of the column in new column

# %%
data["outcome"] = data["-[840801013]"].str[0]
data.drop(columns="-[840801013]", inplace=True)

# %% [markdown]
# --> Replacing all possible disease outcomes into one category - "yes".

# %%
list = ['S', 'F', 'A', 'R', 'I', 'M', 'N', 'G', 'K', 'L', 'Q', 'J',
       'C', 'O', 'H', 'D', 'P', 'B', 'E']
data['outcome'].replace(to_replace=list, value="yes", inplace=True)

# %%
data.head()
# Out:
#    29  F  f f.1 f.2 f.3 f.4 f.5 f.6  t  ... f.14  ?.1 f.15 ?.2 f.16 ?.3 f.17  \
# 0  29  F  f   f   f   f   f   f   f  f  ...    t  128    f   ?    f   ?    f
# 1  41  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
# 2  36  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
# 3  32  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
# 4  60  F  f   f   f   f   f   f   f  f  ...    f    ?    f   ?    f   ?    t
#
#   ?.4  other outcome
# 0   ?  other       -
# 1  11  other       -
# 2  26  other       -
# 3  36  other     yes
# 4  26  other       -
#
# [5 rows x 30 columns]

# %% [markdown]
# ---> Replacing the binary outputs into integer values 0 and 1 for simplicity.

# %%
data.outcome.replace({"-":0, "yes":1}, inplace=True)

# %% [markdown]
# ---> Here I replace the column names with more simple and understandable form.

# %%
data.rename(columns = {"29":"age", "F":"sex", "f":"thyroxine", "f.1":"query_thyroxine", "f.2":"medication","f.3":"sick", 
                        "f.4":"pregnant", "f.5":"surgery", "f.6":"I131_treatment", "t":"query_hypothyroid", 
                        "f.7":"query_hyperthyroid", "f.8":"lithium", "f.9":"goitre", "f.10":"tumor", "f.11":"hypopituitary", 
                        "f.12":"psych", "t.1":"TSH_measured","0.3":"TSH", "f.13":"T3_measured", "?":"T3", 
                        "f.14":"TT4_measured", "?.1":"TT4", "f.15":"T4U_measured", "?.2":"T4U", "f.16":"FTI_measured", 
                        "?.3":"FTI", "f.17":"TBG_measured", "?.4":"TBG", "other":"referral_source"}, inplace=True)

# %% [markdown]
# ---> So, basic preprocessing is done on this dataset, so i am saving this dataset for further use

# %%
data.to_csv("data_processed_1.csv", index=False)
